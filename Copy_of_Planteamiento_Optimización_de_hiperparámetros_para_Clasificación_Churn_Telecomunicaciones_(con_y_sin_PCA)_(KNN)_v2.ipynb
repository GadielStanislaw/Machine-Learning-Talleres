# %% [markdown]
# # 📔 **Resolución**
# Una vez que la nota sea entregada, encontrarás la resolución en este link de notion:
#
# https://www.notion.so/Soluciones-MMIA-3era-cohorte-1ea0573743578016a1aac56aaf239271?source=copy_link
#
# Recuerda que existen varias formar de solucionar las actividades propuestas en los laboratorios. Toma la resolución entregada como referencia. En caso de que el link de resolución no esté público, solicita acceso en el mismo link de notion

# %% [markdown]
# # Optimización de hiperparámetros con PCA y sin PCA para la predicción de pérdida de clientes en Empresas de Servicios de Telecomunicaciones (Churn) con KNN
#
#
# Reducir las salidas y [deserciones de clientes](https://www.bain.com/insights/breaking-the-back-of-customer-churn/) se ha convertido en una alta prioridad para la mayoría de los proveedores de servicios de comunicaciones a medida que los mercados maduran y la competencia se intensifica.
#
#
#
#
# En este documento usaremos una base de datos de una empresa de telecomunicaciones anónima [disponibilizada por IBM](https://raw.githubusercontent.com/IBM/telco-customer-churn-on-icp4d/master/data/Telco-Customer-Churn.csv).
#
# El principal objetivo es crear un model de aprendizaje automático basado en KNN (similar al propuesto [aquí con SVM](https://github.com/mmcuri/ds_handson/blob/master/Telecom_Churn_Prediction.ipynb)) para predecir la pérdida o salida de clientes en una empresa de telecomunicaciones.

# %% [markdown]
# ## Librerías
#
# Importamos varias bibliotecas y módulos útiles para el análisis de datos y el aprendizaje automático en Python. A continuación se describe cada uno de ellos:
#
# - `pandas as pd`: Importa la biblioteca Pandas y la renombra como "pd". Pandas es una biblioteca popular utilizada para la manipulación y análisis de datos en Python.
#
# - `numpy as np`: Importa la biblioteca NumPy y la renombra como "np". NumPy es una biblioteca de Python utilizada para realizar operaciones matemáticas en matrices y vectores.
#
# - `matplotlib.pyplot as plt`: Importa la biblioteca Matplotlib y el módulo pyplot y lo renombra como "plt". Matplotlib es una biblioteca utilizada para la visualización de datos en Python.
#
# - `from sklearn.metrics import classification_report`: Importa la función classification_report desde el módulo metrics de la biblioteca scikit-learn. classification_report es una función que calcula y muestra un informe de clasificación detallado para un modelo de clasificación.
#
# - `from sklearn.metrics import confusion_matrix`: Importa la función confusion_matrix desde el módulo metrics de la biblioteca scikit-learn. confusion_matrix es una función que calcula y muestra la matriz de confusión para un modelo de clasificación.
#
# - `from sklearn.metrics import accuracy_score`: Importa la función accuracy_score desde el módulo metrics de la biblioteca scikit-learn. accuracy_score es una función que calcula y muestra la precisión de un modelo de clasificación.
#
# - `from sklearn.metrics import roc_auc_score`: Importa la función roc_auc_score desde el módulo metrics de la biblioteca scikit-learn. roc_auc_score es una función que calcula el área bajo la curva ROC (AUC) para un modelo de clasificación.
#
# - `from sklearn.preprocessing import StandardScaler, LabelEncoder`: Importa las clases StandardScaler y LabelEncoder desde el módulo preprocessing de la biblioteca scikit-learn. StandardScaler es una clase utilizada para estandarizar los datos y LabelEncoder es una clase utilizada para codificar las etiquetas de clase en números enteros.
#
# - `from sklearn.model_selection import train_test_split`: Importa la función train_test_split desde el módulo model_selection de la biblioteca scikit-learn. train_test_split es una función que divide los datos en conjuntos de entrenamiento y prueba para su uso en el modelado predictivo.
#
# En resumen, este código importa varias bibliotecas y módulos que son útiles para el análisis de datos y el aprendizaje automático en Python.

# %%
# importing libraries
import pandas as pd #excel sofisticado
import numpy as np #matlab
import matplotlib.pyplot as plt #plots
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Base de datos
#
# Este conjunto de datos contiene un total de 7043 clientes y 21 características de los mismos. De las entradas, 5174 son clientes activos y 1869 son clientes que la empresa ha perdido. Observe que el conjunto de datos está desbalanceado pues por cada cliente perdido existe casi 3 clientes activos. La variable de salida para nuestro modelo de machine learning será `Churn`.

# %%
# importamos dataset
DATA_PATH = "https://raw.githubusercontent.com/mtgca/datasets_public/main/WA_Fn-UseC_-Telco-Customer-Churn.csv"
df = pd.read_csv(DATA_PATH)
#print(df)
# vemos las primeras 5 filas
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# ### *Detalles de la base de datos*
#
# *	`customerID` - Custumer unique identifier
# *	`gender` - Customer gender - ['Female' 'Male']
# *	`SeniorCitizen` - Elderly or retired person, a senior citizen is someone who has at least attained the age of 60 of 65 years
# *	`Partner` - - ['No' 'Yes']
# *	`Dependents` - If customer has dependents - ['No' 'Yes']
# *	`Tenure` - Customer lifespan (in months)
# *	`PhoneService` - - ['No' 'Yes']
# *	`MultipleLines` - - ['No' 'No phone service' 'Yes']
# *	`InternetService` - - ['No' 'No internet service' 'Yes']
# *	`OnlineSecurity` - - ['No' 'No internet service' 'Yes']
# *	`OnlineBackup` - - ['No' 'No internet service' 'Yes']
# *	`DeviceProtection` - - ['No' 'No internet service' 'Yes']
# *	`TechSupport` - - ['No' 'No internet service' 'Yes']
# *	`StreamingTV` - - ['No' 'No internet service' 'Yes']
# *	`StreamingMovies` -  - ['No' 'No internet service' 'Yes']
# *	`Contract` - Type of contract - ['Month-to-month' 'One year' 'Two year']
# *	`PaperlessBilling` - - ['No' 'Yes']
# *	`PaymentMethod` - payment method - ['Bank transfer (automatic)', 'Credit card (automatic)', 'Electronic check', 'Mailed check']
# *	`MonthlyCharges` - Monthly Recurring Charges
# *	`TotalCharges` - Life time value
# *	`Churn` - Churn value, the targer vector - ['No' 'Yes']

# %% [markdown]
# ### *Limpieza del Dataset*
#
# El código presenta una serie de operaciones de preprocesamiento de datos en una base de datos que contiene información sobre clientes de una compañía, incluyendo su género, edad, servicios contratados, pagos realizados, entre otros.
#
# En primer lugar, se define la función get_df_size para imprimir el número de atributos y entradas de la base de datos.
#
# Luego, se reemplazan los valores en blanco por NaN para facilitar el manejo de valores faltantes en la base de datos.
#
# A continuación, se reemplazan los valores faltantes en la columna 'TotalCharges' por la mediana de esa columna y se convierte esa columna al tipo numérico.
#
# Después, se elimina la columna 'customerID' ya que no es una característica relevante.
#
# A continuación, se codifican las características binarias en 0's y 1's usando LabelEncoder y se imprimen las categorías correspondientes a cada una de estas características.

# %%
def get_df_size(df, header='Dataset dimensions'):
  print(header,
        '\n# Attributes: ', df.shape[1],
        '\n# Entries: ', df.shape[0],'\n')

get_df_size(df)

#df.info()

# reemplaza valores en blanco por NaN
df_clean = df.replace(r'^\s*$', np.nan, regex=True)

# Convert 'TotalCharges' to numeric before calculating the median.
# errors='coerce' will handle any non-numeric values by setting them to NaN.
df_clean['TotalCharges'] = pd.to_numeric(df_clean['TotalCharges'], errors='coerce')

# reemplaza valores faltantes en TotalCharges por la mediana de TotalCharges.
total_charges_median = df_clean.TotalCharges.median()
df_clean['TotalCharges'].fillna(total_charges_median, inplace=True)
df_clean['TotalCharges'] = df_clean['TotalCharges'].apply(pd.to_numeric)

#CustomerID lo retiramos porque no es una característica
df_clean = df_clean.drop('customerID', axis=1)
df_clean.describe()

print("Churn No Instances: ", df_clean[df_clean['Churn'] == 'No'].shape[0])
print("Churn Yes Instances: ", df_clean[df_clean['Churn'] == 'Yes'].shape[0])

binary_feat = df_clean.nunique()[df_clean.nunique() == 2].keys().tolist()
numeric_feat = [col for col in df_clean.select_dtypes(['float','int']).columns.tolist() if col not in binary_feat]
categorical_feat = [ col for col in df_clean.select_dtypes('object').columns.to_list() if col not in binary_feat + numeric_feat ]
df_proc = df_clean.copy()
#Etiquetas para características binarias
le = LabelEncoder()
for i in binary_feat:
  df_proc[i] = le.fit_transform(df_proc[i])
  print(i, '\n', np.unique(df_proc[i].values))
#Dummy variables
df_proc = pd.get_dummies(df_proc, columns=categorical_feat)
get_df_size(df, header='Original dataset:')
get_df_size(df_proc, header='Processed dataset:')
df_proc.head()
# Out:
# Dataset dimensions
# # Attributes:  21
# # Entries:  7043
# /tmp/ipykernel_17228/2470922283.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean['TotalCharges'].fillna(total_charges_median, inplace=True)
# Churn No Instances:  5174
# Churn Yes Instances:  1869
# gender
#  [0 1]
# SeniorCitizen
#  [0 1]
# Partner
#  [0 1]
# Dependents
#  [0 1]
# PhoneService
#  [0 1]
# PaperlessBilling
#  [0 1]
# Churn
#  [0 1]
# Original dataset:
# # Attributes:  21
# # Entries:  7043
#
# Processed dataset:
# # Attributes:  41
# # Entries:  7043
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    PaperlessBilling  MonthlyCharges  TotalCharges  Churn  ...  \
# 0                 1           29.85         29.85      0  ...
# 1                 0           56.95       1889.50      0  ...
# 2                 1           53.85        108.15      1  ...
# 3                 0           42.30       1840.75      0  ...
# 4                 1           70.70        151.65      1  ...
#
#    StreamingMovies_No  StreamingMovies_No internet service  \
# 0                True                                False
# 1                True                                False
# 2                True                                False
# 3                True                                False
# 4                True                                False
#
#    StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 0                False                     True              False
# 1                False                    False               True
# 2                False                     True              False
# 3                False                    False               True
# 4                False                     True              False
#
#    Contract_Two year  PaymentMethod_Bank transfer (automatic)  \
# 0              False                                    False
# 1              False                                    False
# 2              False                                    False
# 3              False                                     True
# 4              False                                    False
#
#    PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
# 3                                  False                           False
# 4                                  False                            True
#
#    PaymentMethod_Mailed check
# 0                       False
# 1                        True
# 2                        True
# 3                       False
# 4                       False
#
# [5 rows x 41 columns]

# %% [markdown]
# ### *División en conjunto de entrenamiento y test*
#
# En el código, se divide el conjunto de datos df_proc en características y variable objetivo X e y, respectivamente. Luego, se realiza una división de los datos en conjuntos de entrenamiento y prueba utilizando la función train_test_split de scikit-learn. Los conjuntos de entrenamiento y prueba se almacenan en X_train, X_test, y_train y y_test. La división se realiza de manera estratificada para asegurar que la proporción de instancias positivas y negativas en la variable objetivo se mantenga en ambos conjuntos. Se utiliza una proporción de 80/20 para los conjuntos de entrenamiento y prueba, respectivamente, y se fija una semilla aleatoria (random_state) en 42 para asegurar que los resultados sean reproducibles.

# %%
# dividimos df_proc en características y salida
X=df_proc.drop('Churn', axis=1) #features
y=df_proc['Churn'] #output, target

# Dividimos el conjunto de entrenamiento y test
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# %% [markdown]
# ### *Balanceo de datos*
#
# Este código realiza el submuestreo (undersampling) de un conjunto de datos desbalanceado en términos de la variable objetivo. El submuestreo se utiliza para abordar el problema del desequilibrio de clases en el conjunto de datos, donde una o varias clases tienen muchas menos observaciones que las otras clases. En este caso, el modelo de aprendizaje automático puede estar sesgado hacia la clase mayoritaria, lo que puede resultar en un rendimiento deficiente en la clasificación de la clase minoritaria.
#
# El submuestreo implica reducir el número de observaciones en la clase mayoritaria para equilibrar la distribución de las clases en el conjunto de datos. Esto puede mejorar el rendimiento del modelo en la clasificación de la clase minoritaria y reducir el sesgo hacia la clase mayoritaria.
#
# La biblioteca imblearn se utiliza para realizar el submuestreo, y en este caso se importa la clase RandomUnderSampler. El objeto RandomUnderSampler se inicializa con random_state=1, lo que garantiza que los resultados serán reproducibles.
#
# Luego, el submuestreo se realiza en el conjunto de entrenamiento (X_train, y_train) mediante el método fit_resample del objeto rus. Los datos submuestreados se almacenan en X_train_rus y y_train_rus.
#
# Para evaluar el efecto del submuestreo, se utiliza la función get_df_size, que devuelve el tamaño del conjunto de datos. Primero se imprime el tamaño del conjunto de entrenamiento original (X_train, y_train) antes del submuestreo, y luego se imprime el tamaño del conjunto submuestreado (X_train_rus, y_train_rus) después de aplicar el submuestreo.
#
# Finalmente, se utiliza la función np.unique para verificar que las categorías de la variable objetivo (y_train_rus) estén balanceadas. La función devuelve una tupla que contiene las categorías únicas y el número de instancias en cada categoría. Al utilizar return_counts=True, se garantiza que se devuelvan los recuentos de las categorías.

# %%
# submuestreo -> under sampling
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state=1)
X_train_undersampled, y_train_undersampled = rus.fit_resample(X_train, y_train)
get_df_size(X_train, header='Before balancing:')
get_df_size(X_train_undersampled, header='After balancing:')

# verificamos que las categorias estén balanceadas
np.unique(y_train_undersampled, return_counts=True)
# Out:
# Before balancing:
# # Attributes:  40
# # Entries:  5634
#
# After balancing:
# # Attributes:  40
# # Entries:  2990
# (array([0, 1]), array([1495, 1495]))

# %% [markdown]
# ## Modelo de Machine Learning
#
# En este segmento de código se utiliza el algoritmo de K-Vecinos Más Cercanos (KNN) para clasificar los datos de entrada. Primero, se crea un objeto de Pipeline que combina varios pasos de preprocesamiento y entrenamiento del modelo. Los pasos incluyen:
#
# `polynomial_features`: Esta función transforma las características de entrada en una forma polinomial para hacer posible un mejor ajuste del modelo.
#
# `scaler`: Normaliza las características de entrada para que todas tengan una media cero y una varianza unitaria.
#
# `knn`: Un clasificador KNN que utiliza un número especificado de vecinos para determinar la clase de un punto de datos.
#
# Una vez que se define el objeto de Pipeline, se ajusta al conjunto de entrenamiento utilizando el método fit(). Luego se utiliza el modelo ajustado para predecir las clases de los puntos de datos en el conjunto de prueba y en el conjunto de entrenamiento. Esto se hace mediante el método predict(). Finalmente, se utiliza la métrica de precisión (accuracy_score) de la biblioteca sklearn.metrics para evaluar la precisión del modelo en el conjunto de prueba y en el conjunto de entrenamiento.

# %% [markdown]
# ### K Nearest Neighbors sin optimización de hiperparámetros

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
import sklearn.metrics as metrics
from sklearn.preprocessing import PolynomialFeatures

# pipeline
pipeline_knn = Pipeline([
    # ('polynomial_features', PolynomialFeatures(degree=2)),
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier()) #parámetros por default
])

# training
pipeline_knn.fit(X_train_undersampled, y_train_undersampled)

# evaluation on test
pred_test = pipeline_knn.predict(X_test)
f1score = metrics.f1_score(y_test, pred_test)
acc = metrics.accuracy_score(y_test, pred_test)
preci = metrics.precision_score(y_test, pred_test)
recall = metrics.recall_score(y_test, pred_test)

print("Para el modelo NO optimizado, métricas en el conjunto de test: recall = ", recall, ", F1 = ", f1score, ", acc = ", acc, ", precision = ", preci, )

# %% [markdown]
# ### Optimización de Hiperparámetros KNN con kfold CV sin PCA
#
# Usamos k-fold cross-validation (ver `GridSearchCV` y  `StratifiedKFold`) para optimizar los siguientes hiperparámetros de KNN en el conjunto de entrenamiento balanceado (`X_train_undersampled`, `y_train_undersampled`):
#
# 1. Ponderación de vecinos: sin ponderación, ponderación del inverso de la distancia
# 2. Número de vecinos: rango 1 a 100.
# 3. Métricas de distancia: euclideana, manhattan, coseno
#
# Para la optimización de hiperparámetros utilizamos como métrica al recall.
#
# Una vez optimizados los hiperparámetros, reentrenamos el clasificador de kNN con los mejores hiperparámetros encontrados. Finalmente, evaluamos este último clasificador en el conjunto de test `X_test`, `y_test`.)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

#optimización
kfold = StratifiedKFold(n_splits=2, shuffle=True, random_state=45) #para nsplits=5 demora 35 min approx en google colab.

# pipeline
pipeline_knn = Pipeline([
     #('polynomial_features', PolynomialFeatures(degree=2)),
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier())
])
param_grid = {'knn__weights': ['uniform', 'distance'], #uniform es sin ponderación, weighted knn
              'knn__n_neighbors': np.arange(1,101,1), #1 a 100.
              'knn__metric': ['euclidean', 'manhattan', 'cosine']}


search = GridSearchCV(pipeline_knn, param_grid, scoring='recall', cv=kfold, verbose=4)
result = search.fit(X_train_undersampled, y_train_undersampled)

print(f'Mejor recall en el conj. de validación: {result.best_score_} para {result.best_params_}')

#reentreno con mejores
pipeline_knn.set_params(knn__n_neighbors=result.best_params_['knn__n_neighbors'],
                       knn__weights=result.best_params_['knn__weights'],
                       knn__metric=result.best_params_['knn__metric'])
pipeline_knn.fit(X_train_undersampled, y_train_undersampled)

#evaluamos en el conjunto de test
pred_test = pipeline_knn.predict(X_test)
f1score = metrics.f1_score(y_test, pred_test)
acc = metrics.accuracy_score(y_test, pred_test)
preci = metrics.precision_score(y_test, pred_test)
recall = metrics.recall_score(y_test, pred_test)

print("Para el modelo optimizado, métricas en el conjunto de test: recall = ", recall, ", F1 = ", f1score, ", acc = ", acc, ", precision = ", preci, )

# %% [markdown]
# ### Optimización de hiperparámetros kNN con PCA
#
# Repetiremos el proceso anterior pero esta vez con PCA

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA

#optimización
kfold = StratifiedKFold(n_splits=2, shuffle=True, random_state=45) #para nsplits=5 demora 35 min approx en google colab.

# pipeline
pipeline_knn_pca = Pipeline([
     #('polynomial_features', PolynomialFeatures(degree=2)),
    ('scaler', StandardScaler()),
    ('pca', PCA(n_components=0.95)),
    ('knn', KNeighborsClassifier())
])
param_grid = {'knn__weights': ['uniform', 'distance'],
              'knn__n_neighbors': np.arange(1,101,1),
              'knn__metric': ['euclidean', 'manhattan', 'cosine']}


search = GridSearchCV(pipeline_knn_pca, param_grid, scoring='recall', cv=kfold, verbose=4)
result = search.fit(X_train_undersampled, y_train_undersampled)

print(f'Mejor recall en el conj. de validación: {result.best_score_} para {result.best_params_}')

#reentreno con mejores
pipeline_knn_pca.set_params(knn__n_neighbors=result.best_params_['knn__n_neighbors'],
                       knn__weights=result.best_params_['knn__weights'],
                       knn__metric=result.best_params_['knn__metric'])
pipeline_knn_pca.fit(X_train_undersampled, y_train_undersampled)

#evaluamos en el conjunto de test
pred_test = pipeline_knn_pca.predict(X_test)
f1score = metrics.f1_score(y_test, pred_test)
acc = metrics.accuracy_score(y_test, pred_test)
preci = metrics.precision_score(y_test, pred_test)
recall = metrics.recall_score(y_test, pred_test)

print("Para el modelo optimizado, métricas en el conjunto de test: recall = ", recall, ", F1 = ", f1score, ", acc = ", acc, ", precision = ", preci, )
# Out:
# Fitting 2 folds for each of 600 candidates, totalling 1200 fits
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=1, knn__weights=uniform;, score=0.696 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=1, knn__weights=uniform;, score=0.646 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=1, knn__weights=distance;, score=0.696 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=1, knn__weights=distance;, score=0.646 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=2, knn__weights=uniform;, score=0.530 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=2, knn__weights=uniform;, score=0.507 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=2, knn__weights=distance;, score=0.696 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=2, knn__weights=distance;, score=0.646 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform;, score=0.740 total time=   0.0s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform;, score=0.723 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance;, score=0.722 total time=   0.0s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance;, score=0.702 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=4, knn__weights=uniform;, score=0.657 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=4, knn__weights=uniform;, score=0.628 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=4, knn__weights=distance;, score=0.727 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=4, knn__weights=distance;, score=0.697 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform;, score=0.782 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform;, score=0.749 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance;, score=0.751 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance;, score=0.721 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=6, knn__weights=uniform;, score=0.723 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=6, knn__weights=uniform;, score=0.684 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=6, knn__weights=distance;, score=0.759 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=6, knn__weights=distance;, score=0.725 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform;, score=0.809 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform;, score=0.775 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance;, score=0.780 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance;, score=0.741 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=8, knn__weights=uniform;, score=0.756 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=8, knn__weights=uniform;, score=0.737 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=8, knn__weights=distance;, score=0.780 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=8, knn__weights=distance;, score=0.743 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform;, score=0.813 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform;, score=0.791 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance;, score=0.780 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance;, score=0.758 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=10, knn__weights=uniform;, score=0.783 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=10, knn__weights=uniform;, score=0.771 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=10, knn__weights=distance;, score=0.788 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=10, knn__weights=distance;, score=0.761 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform;, score=0.829 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform;, score=0.810 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance;, score=0.798 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance;, score=0.774 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=12, knn__weights=uniform;, score=0.802 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=12, knn__weights=uniform;, score=0.791 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=12, knn__weights=distance;, score=0.802 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=12, knn__weights=distance;, score=0.773 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=13, knn__weights=uniform;, score=0.833 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=13, knn__weights=uniform;, score=0.814 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=13, knn__weights=distance;, score=0.807 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=13, knn__weights=distance;, score=0.777 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=14, knn__weights=uniform;, score=0.817 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=14, knn__weights=uniform;, score=0.790 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=14, knn__weights=distance;, score=0.809 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=14, knn__weights=distance;, score=0.783 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform;, score=0.833 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform;, score=0.820 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance;, score=0.810 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance;, score=0.786 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=16, knn__weights=uniform;, score=0.811 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=16, knn__weights=uniform;, score=0.802 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=16, knn__weights=distance;, score=0.810 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=16, knn__weights=distance;, score=0.794 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=17, knn__weights=uniform;, score=0.822 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=17, knn__weights=uniform;, score=0.821 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=17, knn__weights=distance;, score=0.807 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=17, knn__weights=distance;, score=0.794 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=18, knn__weights=uniform;, score=0.809 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=18, knn__weights=uniform;, score=0.807 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=18, knn__weights=distance;, score=0.811 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=18, knn__weights=distance;, score=0.799 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=19, knn__weights=uniform;, score=0.827 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=19, knn__weights=uniform;, score=0.833 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=19, knn__weights=distance;, score=0.817 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=19, knn__weights=distance;, score=0.805 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=20, knn__weights=uniform;, score=0.818 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=20, knn__weights=uniform;, score=0.813 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=20, knn__weights=distance;, score=0.819 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=20, knn__weights=distance;, score=0.807 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=21, knn__weights=uniform;, score=0.838 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=21, knn__weights=uniform;, score=0.829 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=21, knn__weights=distance;, score=0.818 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=21, knn__weights=distance;, score=0.807 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=22, knn__weights=uniform;, score=0.823 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=22, knn__weights=uniform;, score=0.818 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=22, knn__weights=distance;, score=0.819 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=22, knn__weights=distance;, score=0.809 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=23, knn__weights=uniform;, score=0.837 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=23, knn__weights=uniform;, score=0.829 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=23, knn__weights=distance;, score=0.822 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=23, knn__weights=distance;, score=0.807 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=24, knn__weights=uniform;, score=0.827 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=24, knn__weights=uniform;, score=0.818 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=24, knn__weights=distance;, score=0.822 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=24, knn__weights=distance;, score=0.810 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=25, knn__weights=uniform;, score=0.843 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=25, knn__weights=uniform;, score=0.830 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=25, knn__weights=distance;, score=0.823 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=25, knn__weights=distance;, score=0.811 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=26, knn__weights=uniform;, score=0.831 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=26, knn__weights=uniform;, score=0.828 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=26, knn__weights=distance;, score=0.827 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=26, knn__weights=distance;, score=0.817 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=27, knn__weights=uniform;, score=0.847 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=27, knn__weights=uniform;, score=0.836 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=27, knn__weights=distance;, score=0.830 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=27, knn__weights=distance;, score=0.817 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=28, knn__weights=uniform;, score=0.839 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=28, knn__weights=uniform;, score=0.828 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=28, knn__weights=distance;, score=0.835 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=28, knn__weights=distance;, score=0.817 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=29, knn__weights=uniform;, score=0.845 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=29, knn__weights=uniform;, score=0.833 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=29, knn__weights=distance;, score=0.834 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=29, knn__weights=distance;, score=0.816 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=30, knn__weights=uniform;, score=0.845 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=30, knn__weights=uniform;, score=0.828 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=30, knn__weights=distance;, score=0.843 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=30, knn__weights=distance;, score=0.818 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=31, knn__weights=uniform;, score=0.851 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=31, knn__weights=uniform;, score=0.836 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=31, knn__weights=distance;, score=0.839 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=31, knn__weights=distance;, score=0.821 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=32, knn__weights=uniform;, score=0.846 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=32, knn__weights=uniform;, score=0.830 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=32, knn__weights=distance;, score=0.845 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=32, knn__weights=distance;, score=0.826 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=33, knn__weights=uniform;, score=0.849 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=33, knn__weights=uniform;, score=0.837 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=33, knn__weights=distance;, score=0.841 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=33, knn__weights=distance;, score=0.821 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=34, knn__weights=uniform;, score=0.843 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=34, knn__weights=uniform;, score=0.826 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=34, knn__weights=distance;, score=0.842 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=34, knn__weights=distance;, score=0.820 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=35, knn__weights=uniform;, score=0.851 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=35, knn__weights=uniform;, score=0.833 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=35, knn__weights=distance;, score=0.842 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=35, knn__weights=distance;, score=0.818 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=36, knn__weights=uniform;, score=0.846 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=36, knn__weights=uniform;, score=0.824 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=36, knn__weights=distance;, score=0.843 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=36, knn__weights=distance;, score=0.816 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=37, knn__weights=uniform;, score=0.854 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=37, knn__weights=uniform;, score=0.830 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=37, knn__weights=distance;, score=0.846 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=37, knn__weights=distance;, score=0.814 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=38, knn__weights=uniform;, score=0.849 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=38, knn__weights=uniform;, score=0.828 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=38, knn__weights=distance;, score=0.846 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=38, knn__weights=distance;, score=0.820 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=39, knn__weights=uniform;, score=0.855 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=39, knn__weights=uniform;, score=0.834 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=39, knn__weights=distance;, score=0.847 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=39, knn__weights=distance;, score=0.821 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=40, knn__weights=uniform;, score=0.850 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=40, knn__weights=uniform;, score=0.829 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=40, knn__weights=distance;, score=0.845 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=40, knn__weights=distance;, score=0.824 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=41, knn__weights=uniform;, score=0.855 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=41, knn__weights=uniform;, score=0.836 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=41, knn__weights=distance;, score=0.843 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=41, knn__weights=distance;, score=0.825 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=42, knn__weights=uniform;, score=0.851 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=42, knn__weights=uniform;, score=0.829 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=42, knn__weights=distance;, score=0.846 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=42, knn__weights=distance;, score=0.822 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=43, knn__weights=uniform;, score=0.854 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=43, knn__weights=uniform;, score=0.834 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=43, knn__weights=distance;, score=0.849 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=43, knn__weights=distance;, score=0.822 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=44, knn__weights=uniform;, score=0.850 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=44, knn__weights=uniform;, score=0.829 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=44, knn__weights=distance;, score=0.850 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=44, knn__weights=distance;, score=0.826 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=45, knn__weights=uniform;, score=0.853 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=45, knn__weights=uniform;, score=0.834 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=45, knn__weights=distance;, score=0.850 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=45, knn__weights=distance;, score=0.826 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=46, knn__weights=uniform;, score=0.850 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=46, knn__weights=uniform;, score=0.829 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=46, knn__weights=distance;, score=0.850 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=46, knn__weights=distance;, score=0.825 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=47, knn__weights=uniform;, score=0.859 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=47, knn__weights=uniform;, score=0.836 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=47, knn__weights=distance;, score=0.851 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=47, knn__weights=distance;, score=0.826 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=48, knn__weights=uniform;, score=0.853 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=48, knn__weights=uniform;, score=0.830 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=48, knn__weights=distance;, score=0.851 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=48, knn__weights=distance;, score=0.825 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=49, knn__weights=uniform;, score=0.861 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=49, knn__weights=uniform;, score=0.838 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=49, knn__weights=distance;, score=0.853 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=49, knn__weights=distance;, score=0.828 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=50, knn__weights=uniform;, score=0.850 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=50, knn__weights=uniform;, score=0.832 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=50, knn__weights=distance;, score=0.853 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=50, knn__weights=distance;, score=0.825 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=51, knn__weights=uniform;, score=0.857 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=51, knn__weights=uniform;, score=0.840 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=51, knn__weights=distance;, score=0.854 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=51, knn__weights=distance;, score=0.830 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=52, knn__weights=uniform;, score=0.855 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=52, knn__weights=uniform;, score=0.836 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=52, knn__weights=distance;, score=0.853 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=52, knn__weights=distance;, score=0.833 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=53, knn__weights=uniform;, score=0.855 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=53, knn__weights=uniform;, score=0.844 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=53, knn__weights=distance;, score=0.855 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=53, knn__weights=distance;, score=0.836 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=54, knn__weights=uniform;, score=0.850 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=54, knn__weights=uniform;, score=0.840 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=54, knn__weights=distance;, score=0.851 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=54, knn__weights=distance;, score=0.834 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=55, knn__weights=uniform;, score=0.854 total time=   0.4s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=55, knn__weights=uniform;, score=0.845 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=55, knn__weights=distance;, score=0.851 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=55, knn__weights=distance;, score=0.840 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=56, knn__weights=uniform;, score=0.851 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=56, knn__weights=uniform;, score=0.841 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=56, knn__weights=distance;, score=0.853 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=56, knn__weights=distance;, score=0.837 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=57, knn__weights=uniform;, score=0.854 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=57, knn__weights=uniform;, score=0.846 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=57, knn__weights=distance;, score=0.850 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=57, knn__weights=distance;, score=0.840 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=58, knn__weights=uniform;, score=0.854 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=58, knn__weights=uniform;, score=0.842 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=58, knn__weights=distance;, score=0.854 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=58, knn__weights=distance;, score=0.838 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=59, knn__weights=uniform;, score=0.855 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=59, knn__weights=uniform;, score=0.845 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=59, knn__weights=distance;, score=0.853 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=59, knn__weights=distance;, score=0.837 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=60, knn__weights=uniform;, score=0.850 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=60, knn__weights=uniform;, score=0.844 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=60, knn__weights=distance;, score=0.853 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=60, knn__weights=distance;, score=0.840 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=61, knn__weights=uniform;, score=0.857 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=61, knn__weights=uniform;, score=0.848 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=61, knn__weights=distance;, score=0.851 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=61, knn__weights=distance;, score=0.838 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=62, knn__weights=uniform;, score=0.854 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=62, knn__weights=uniform;, score=0.846 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=62, knn__weights=distance;, score=0.854 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=62, knn__weights=distance;, score=0.841 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=63, knn__weights=uniform;, score=0.857 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=63, knn__weights=uniform;, score=0.849 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=63, knn__weights=distance;, score=0.855 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=63, knn__weights=distance;, score=0.841 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=64, knn__weights=uniform;, score=0.854 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=64, knn__weights=uniform;, score=0.848 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=64, knn__weights=distance;, score=0.855 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=64, knn__weights=distance;, score=0.841 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=65, knn__weights=uniform;, score=0.857 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=65, knn__weights=uniform;, score=0.850 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=65, knn__weights=distance;, score=0.857 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=65, knn__weights=distance;, score=0.844 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=66, knn__weights=uniform;, score=0.855 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=66, knn__weights=uniform;, score=0.849 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=66, knn__weights=distance;, score=0.857 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=66, knn__weights=distance;, score=0.842 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=67, knn__weights=uniform;, score=0.859 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=67, knn__weights=uniform;, score=0.850 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=67, knn__weights=distance;, score=0.857 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=67, knn__weights=distance;, score=0.842 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=68, knn__weights=uniform;, score=0.855 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=68, knn__weights=uniform;, score=0.848 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=68, knn__weights=distance;, score=0.858 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=68, knn__weights=distance;, score=0.844 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=69, knn__weights=uniform;, score=0.861 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=69, knn__weights=uniform;, score=0.850 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=69, knn__weights=distance;, score=0.857 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=69, knn__weights=distance;, score=0.844 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=70, knn__weights=uniform;, score=0.855 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=70, knn__weights=uniform;, score=0.848 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=70, knn__weights=distance;, score=0.857 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=70, knn__weights=distance;, score=0.844 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=71, knn__weights=uniform;, score=0.858 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=71, knn__weights=uniform;, score=0.850 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=71, knn__weights=distance;, score=0.858 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=71, knn__weights=distance;, score=0.845 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=72, knn__weights=uniform;, score=0.854 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=72, knn__weights=uniform;, score=0.849 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=72, knn__weights=distance;, score=0.855 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=72, knn__weights=distance;, score=0.844 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=73, knn__weights=uniform;, score=0.858 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=73, knn__weights=uniform;, score=0.850 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=73, knn__weights=distance;, score=0.854 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=73, knn__weights=distance;, score=0.845 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=74, knn__weights=uniform;, score=0.858 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=74, knn__weights=uniform;, score=0.848 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=74, knn__weights=distance;, score=0.855 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=74, knn__weights=distance;, score=0.844 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=75, knn__weights=uniform;, score=0.859 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=75, knn__weights=uniform;, score=0.850 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=75, knn__weights=distance;, score=0.855 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=75, knn__weights=distance;, score=0.844 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=76, knn__weights=uniform;, score=0.858 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=76, knn__weights=uniform;, score=0.850 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=76, knn__weights=distance;, score=0.858 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=76, knn__weights=distance;, score=0.844 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=77, knn__weights=uniform;, score=0.859 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=77, knn__weights=uniform;, score=0.853 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=77, knn__weights=distance;, score=0.857 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=77, knn__weights=distance;, score=0.846 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=78, knn__weights=uniform;, score=0.858 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=78, knn__weights=uniform;, score=0.846 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=78, knn__weights=distance;, score=0.857 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=78, knn__weights=distance;, score=0.841 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=79, knn__weights=uniform;, score=0.862 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=79, knn__weights=uniform;, score=0.850 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=79, knn__weights=distance;, score=0.861 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=79, knn__weights=distance;, score=0.845 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=80, knn__weights=uniform;, score=0.861 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=80, knn__weights=uniform;, score=0.846 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=80, knn__weights=distance;, score=0.861 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=80, knn__weights=distance;, score=0.841 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=81, knn__weights=uniform;, score=0.861 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=81, knn__weights=uniform;, score=0.852 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=81, knn__weights=distance;, score=0.862 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=81, knn__weights=distance;, score=0.844 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=82, knn__weights=uniform;, score=0.859 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=82, knn__weights=uniform;, score=0.852 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=82, knn__weights=distance;, score=0.858 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=82, knn__weights=distance;, score=0.845 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=83, knn__weights=uniform;, score=0.861 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=83, knn__weights=uniform;, score=0.852 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=83, knn__weights=distance;, score=0.861 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=83, knn__weights=distance;, score=0.845 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=84, knn__weights=uniform;, score=0.859 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=84, knn__weights=uniform;, score=0.850 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=84, knn__weights=distance;, score=0.861 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=84, knn__weights=distance;, score=0.846 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=85, knn__weights=uniform;, score=0.862 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=85, knn__weights=uniform;, score=0.852 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=85, knn__weights=distance;, score=0.859 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=85, knn__weights=distance;, score=0.848 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=86, knn__weights=uniform;, score=0.859 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=86, knn__weights=uniform;, score=0.850 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=86, knn__weights=distance;, score=0.859 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=86, knn__weights=distance;, score=0.848 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=87, knn__weights=uniform;, score=0.862 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=87, knn__weights=uniform;, score=0.856 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=87, knn__weights=distance;, score=0.859 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=87, knn__weights=distance;, score=0.852 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=88, knn__weights=uniform;, score=0.859 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=88, knn__weights=uniform;, score=0.852 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=88, knn__weights=distance;, score=0.858 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=88, knn__weights=distance;, score=0.850 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=89, knn__weights=uniform;, score=0.863 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=89, knn__weights=uniform;, score=0.854 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=89, knn__weights=distance;, score=0.859 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=89, knn__weights=distance;, score=0.850 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=90, knn__weights=uniform;, score=0.861 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=90, knn__weights=uniform;, score=0.852 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=90, knn__weights=distance;, score=0.862 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=90, knn__weights=distance;, score=0.850 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=91, knn__weights=uniform;, score=0.866 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=91, knn__weights=uniform;, score=0.853 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=91, knn__weights=distance;, score=0.861 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=91, knn__weights=distance;, score=0.850 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=92, knn__weights=uniform;, score=0.861 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=92, knn__weights=uniform;, score=0.853 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=92, knn__weights=distance;, score=0.862 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=92, knn__weights=distance;, score=0.853 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=93, knn__weights=uniform;, score=0.863 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=93, knn__weights=uniform;, score=0.857 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=93, knn__weights=distance;, score=0.863 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=93, knn__weights=distance;, score=0.852 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=94, knn__weights=uniform;, score=0.863 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=94, knn__weights=uniform;, score=0.854 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=94, knn__weights=distance;, score=0.865 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=94, knn__weights=distance;, score=0.854 total time=   0.1s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=95, knn__weights=uniform;, score=0.867 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=95, knn__weights=uniform;, score=0.857 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=95, knn__weights=distance;, score=0.865 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=95, knn__weights=distance;, score=0.854 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=96, knn__weights=uniform;, score=0.862 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=96, knn__weights=uniform;, score=0.854 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=96, knn__weights=distance;, score=0.859 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=96, knn__weights=distance;, score=0.856 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=97, knn__weights=uniform;, score=0.865 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=97, knn__weights=uniform;, score=0.857 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=97, knn__weights=distance;, score=0.863 total time=   0.1s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=97, knn__weights=distance;, score=0.854 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=98, knn__weights=uniform;, score=0.862 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=98, knn__weights=uniform;, score=0.854 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=98, knn__weights=distance;, score=0.861 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=98, knn__weights=distance;, score=0.856 total time=   0.2s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=99, knn__weights=uniform;, score=0.866 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=99, knn__weights=uniform;, score=0.857 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=99, knn__weights=distance;, score=0.865 total time=   0.3s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=99, knn__weights=distance;, score=0.856 total time=   0.4s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=100, knn__weights=uniform;, score=0.863 total time=   0.2s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=100, knn__weights=uniform;, score=0.856 total time=   0.3s
# [CV 1/2] END knn__metric=euclidean, knn__n_neighbors=100, knn__weights=distance;, score=0.862 total time=   0.4s
# [CV 2/2] END knn__metric=euclidean, knn__n_neighbors=100, knn__weights=distance;, score=0.856 total time=   0.3s
# [CV 1/2] END knn__metric=manhattan, knn__n_neighbors=1, knn__weights=uniform;, score=0.697 total time=   0.2s
# [CV 2/2] END knn__metric=manhattan, knn__n_neighbors=1, knn__weights=uniform;, score=0.663 total time=   0.2s
# [CV 1/2] END knn__metric=manhattan, knn__n_neighbors=1, knn__weights=distance;, score=0.697 total time=   0.2s
# [CV 2/2] END knn__metric=manhattan, knn__n_neighbors=1, knn__weights=distance;, score=0.663 total time=   0.1s
# [CV 1/2] END knn__metric=manhattan, knn__n_neighbors=2, knn__weights=uniform;, score=0.533 total time=   0.1s
# [CV 2/2] END knn__metric=manhattan, knn__n_neighbors=2, knn__weights=uniform;, score=0.515 total time=   0.2s
# [CV 1/2] END knn__metric=manhattan, knn__n_neighbors=2, knn__weights=distance;, score=0.697 total time=   0.1s
# [CV 2/2] END knn__metric=manhattan, knn__n_neighbors=2, knn__weights=distance;, score=0.663 total time=   0.1s
# [CV 1/2] END knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform;, score=0.747 total time=   0.1s
# [CV 2/2] END knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform;, score=0.717 total time=   0.2s
# [CV 1/2] END knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance;, score=0.718 total time=   0.2s
# [CV 2/2] END knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance;, score=0.693 total time=   0.2s
# [CV 1/2] END knn__metric=manhattan, knn__n_neighbors=4, knn__weights=uniform;, score=0.656 total time=   0.2s
# [CV 2/2] END knn__metric=manhattan, knn__n_neighbors=4, knn__weights=uniform;, score=0.628 total time=   0.2s
# [CV 1/2] END knn__metric=manhattan, knn__n_neighbors=4, knn__weights=distance;, score=0.732 total time=   0.2s
# [CV 2/2] END knn__metric=manhattan, knn__n_neighbors=4, knn__weights=distance;, score=0.691 total time=   0.1s
# [CV 1/2] END knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform;, score=0.786 total time=   0.1s
# [CV 2/2] END knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform;, score=0.741 total time=   0.2s
# [CV 1/2] END knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance;, score=0.742 total time=   0.2s
# [CV 2/2] END knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance;, score=0.717 total time=   0.2s
# [CV 1/2] END knn__metric=manhattan, knn__n_neighbors=6, knn__weights=uniform;, score=0.708 total time=   0.2s
# [CV 2/2] END knn__metric=manhattan, knn__n_neighbors=6, knn__weights=uniform;, score=0.687 total time=   0.1s
# [CV 1/2] END knn__metric=manhattan, knn__n_neighbors=6, knn__weights=distance;, score=0.748 total time=   0.2s
# [CV 2/2] END knn__metric=manhattan, knn__n_neighbors=6, knn__weights=distance;, score=0.718 total time=   0.3s
# [CV 1/2] END knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform;, score=0.806 total time=   0.2s
# [CV 2/2] END knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform;, score=0.755 total time=   0.2s
# [CV 1/2] END knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance;, score=0.756 total time=   0.2s
# [CV 2/2] END knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance;, score=0.726 total time=   0.2s
# [CV 1/2] END knn__metric=manhattan, knn__n_neighbors=8, knn__weights=uniform;, score=0.748 total time=   0.2s
# [CV 2/2] END knn__metric=manhattan, knn__n_neighbors=8, knn__weights=uniform;, score=0.715 total time=   0.2s
# ...
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=65, knn__weights=uniform;, score=0.830 total time=   0.3s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=65, knn__weights=uniform;, score=0.806 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=65, knn__weights=distance;, score=0.791 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=65, knn__weights=distance;, score=0.777 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=66, knn__weights=uniform;, score=0.825 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=66, knn__weights=uniform;, score=0.798 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=66, knn__weights=distance;, score=0.790 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=66, knn__weights=distance;, score=0.779 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=67, knn__weights=uniform;, score=0.829 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=67, knn__weights=uniform;, score=0.801 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=67, knn__weights=distance;, score=0.794 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=67, knn__weights=distance;, score=0.779 total time=   0.3s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=68, knn__weights=uniform;, score=0.827 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=68, knn__weights=uniform;, score=0.799 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=68, knn__weights=distance;, score=0.793 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=68, knn__weights=distance;, score=0.778 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=69, knn__weights=uniform;, score=0.829 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=69, knn__weights=uniform;, score=0.802 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=69, knn__weights=distance;, score=0.794 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=69, knn__weights=distance;, score=0.777 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=70, knn__weights=uniform;, score=0.823 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=70, knn__weights=uniform;, score=0.797 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=70, knn__weights=distance;, score=0.794 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=70, knn__weights=distance;, score=0.774 total time=   0.3s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=71, knn__weights=uniform;, score=0.830 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=71, knn__weights=uniform;, score=0.806 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=71, knn__weights=distance;, score=0.798 total time=   0.3s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=71, knn__weights=distance;, score=0.774 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=72, knn__weights=uniform;, score=0.827 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=72, knn__weights=uniform;, score=0.802 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=72, knn__weights=distance;, score=0.801 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=72, knn__weights=distance;, score=0.771 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=73, knn__weights=uniform;, score=0.831 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=73, knn__weights=uniform;, score=0.809 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=73, knn__weights=distance;, score=0.798 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=73, knn__weights=distance;, score=0.774 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=74, knn__weights=uniform;, score=0.829 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=74, knn__weights=uniform;, score=0.805 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=74, knn__weights=distance;, score=0.799 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=74, knn__weights=distance;, score=0.774 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=75, knn__weights=uniform;, score=0.833 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=75, knn__weights=uniform;, score=0.806 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=75, knn__weights=distance;, score=0.799 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=75, knn__weights=distance;, score=0.778 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=76, knn__weights=uniform;, score=0.830 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=76, knn__weights=uniform;, score=0.803 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=76, knn__weights=distance;, score=0.802 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=76, knn__weights=distance;, score=0.778 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=77, knn__weights=uniform;, score=0.830 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=77, knn__weights=uniform;, score=0.807 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=77, knn__weights=distance;, score=0.801 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=77, knn__weights=distance;, score=0.781 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=78, knn__weights=uniform;, score=0.823 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=78, knn__weights=uniform;, score=0.806 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=78, knn__weights=distance;, score=0.799 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=78, knn__weights=distance;, score=0.777 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=79, knn__weights=uniform;, score=0.829 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=79, knn__weights=uniform;, score=0.807 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=79, knn__weights=distance;, score=0.799 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=79, knn__weights=distance;, score=0.779 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=80, knn__weights=uniform;, score=0.823 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=80, knn__weights=uniform;, score=0.805 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=80, knn__weights=distance;, score=0.799 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=80, knn__weights=distance;, score=0.777 total time=   0.3s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=81, knn__weights=uniform;, score=0.827 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=81, knn__weights=uniform;, score=0.809 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=81, knn__weights=distance;, score=0.798 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=81, knn__weights=distance;, score=0.778 total time=   0.3s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=82, knn__weights=uniform;, score=0.822 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=82, knn__weights=uniform;, score=0.806 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=82, knn__weights=distance;, score=0.799 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=82, knn__weights=distance;, score=0.777 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=83, knn__weights=uniform;, score=0.826 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=83, knn__weights=uniform;, score=0.813 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=83, knn__weights=distance;, score=0.799 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=83, knn__weights=distance;, score=0.775 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=84, knn__weights=uniform;, score=0.822 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=84, knn__weights=uniform;, score=0.807 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=84, knn__weights=distance;, score=0.798 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=84, knn__weights=distance;, score=0.775 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=85, knn__weights=uniform;, score=0.823 total time=   0.3s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=85, knn__weights=uniform;, score=0.814 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=85, knn__weights=distance;, score=0.797 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=85, knn__weights=distance;, score=0.775 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=86, knn__weights=uniform;, score=0.822 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=86, knn__weights=uniform;, score=0.811 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=86, knn__weights=distance;, score=0.798 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=86, knn__weights=distance;, score=0.777 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=87, knn__weights=uniform;, score=0.823 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=87, knn__weights=uniform;, score=0.813 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=87, knn__weights=distance;, score=0.797 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=87, knn__weights=distance;, score=0.777 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=88, knn__weights=uniform;, score=0.821 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=88, knn__weights=uniform;, score=0.809 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=88, knn__weights=distance;, score=0.797 total time=   0.3s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=88, knn__weights=distance;, score=0.777 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=89, knn__weights=uniform;, score=0.826 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=89, knn__weights=uniform;, score=0.811 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=89, knn__weights=distance;, score=0.798 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=89, knn__weights=distance;, score=0.779 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=90, knn__weights=uniform;, score=0.823 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=90, knn__weights=uniform;, score=0.806 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=90, knn__weights=distance;, score=0.799 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=90, knn__weights=distance;, score=0.778 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=91, knn__weights=uniform;, score=0.826 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=91, knn__weights=uniform;, score=0.811 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=91, knn__weights=distance;, score=0.799 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=91, knn__weights=distance;, score=0.778 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=92, knn__weights=uniform;, score=0.821 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=92, knn__weights=uniform;, score=0.807 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=92, knn__weights=distance;, score=0.799 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=92, knn__weights=distance;, score=0.778 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=93, knn__weights=uniform;, score=0.823 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=93, knn__weights=uniform;, score=0.811 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=93, knn__weights=distance;, score=0.798 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=93, knn__weights=distance;, score=0.781 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=94, knn__weights=uniform;, score=0.821 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=94, knn__weights=uniform;, score=0.805 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=94, knn__weights=distance;, score=0.798 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=94, knn__weights=distance;, score=0.778 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=95, knn__weights=uniform;, score=0.823 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=95, knn__weights=uniform;, score=0.811 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=95, knn__weights=distance;, score=0.797 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=95, knn__weights=distance;, score=0.778 total time=   0.3s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=96, knn__weights=uniform;, score=0.822 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=96, knn__weights=uniform;, score=0.810 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=96, knn__weights=distance;, score=0.797 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=96, knn__weights=distance;, score=0.778 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=97, knn__weights=uniform;, score=0.826 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=97, knn__weights=uniform;, score=0.814 total time=   0.1s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=97, knn__weights=distance;, score=0.798 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=97, knn__weights=distance;, score=0.778 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=98, knn__weights=uniform;, score=0.822 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=98, knn__weights=uniform;, score=0.809 total time=   0.3s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=98, knn__weights=distance;, score=0.797 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=98, knn__weights=distance;, score=0.778 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=99, knn__weights=uniform;, score=0.823 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=99, knn__weights=uniform;, score=0.810 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=99, knn__weights=distance;, score=0.799 total time=   0.3s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=99, knn__weights=distance;, score=0.778 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=100, knn__weights=uniform;, score=0.823 total time=   0.1s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=100, knn__weights=uniform;, score=0.809 total time=   0.2s
# [CV 1/2] END knn__metric=cosine, knn__n_neighbors=100, knn__weights=distance;, score=0.801 total time=   0.2s
# [CV 2/2] END knn__metric=cosine, knn__n_neighbors=100, knn__weights=distance;, score=0.781 total time=   0.2s
# Mejor recall en el conj. de validación: 0.8635522482085203 para {'knn__metric': 'manhattan', 'knn__n_neighbors': np.int64(99), 'knn__weights': 'uniform'}
# Para el modelo optimizado, métricas en el conjunto de test: recall =  0.8262032085561497 , F1 =  0.5808270676691729 , acc =  0.6834634492547906 , precision =  0.44782608695652176

# %% [markdown]
# ### ✅ **Actividad: Análisis de resultados: Optimización de hiperparámetros KNN**
#
# Ejecute el código de esta notebook y analice los siguientes casos:
#
# 1. kNN sin PCA
# 2. kNN con PCA
#
# Comente sus resultados analizando los valores de recall, f1 score, accuracy y precisión en el conjunto de test.
#
# Cuál es mejor en términos de recall?
#
# Cuál demora menos en entrenar? Vale la pena usar PCA?
#
# Por qué cree que el recall es una métrica más adecuada para este problema? Tip: El recall está relacionado a los falsos negativos. Analice por qué es importante disminuir los falsos negativos en el churn.

# %% [markdown]
# # ✅ **Actividad**: Bayesian Hyperparameter Optimization
#
# La optimización bayesiana de hiperparámetros es un método avanzado para la selección de los mejores hiperparámetros para un modelo de aprendizaje automático. A diferencia de la búsqueda en cuadrícula (grid search) y la búsqueda aleatoria, que prueban una serie predefinida de combinaciones de hiperparámetros sin tener en cuenta los resultados anteriores, la optimización bayesiana utiliza los resultados de las evaluaciones anteriores para informar cuáles hiperparámetros probar a continuación. Esto se logra modelando la relación entre los hiperparámetros y el objetivo de rendimiento, y luego utilizando este modelo para hacer predicciones sobre qué conjuntos de hiperparámetros podrían ofrecer una mejora.
#
# Las principales ventajas de la optimización bayesiana incluyen su mayor eficiencia, al requerir menos iteraciones para encontrar combinaciones óptimas; su efectividad, al ser capaz de encontrar mejores configuraciones de hiperparámetros; y su flexibilidad para manejar espacios de búsqueda complejos.
#
# Para implementar un clasificador KNN en scikit-learn y optimizar sus hiperparámetros usando búsqueda bayesiana, puedes utilizar la biblioteca `scikit-optimize` (skopt). Esta biblioteca proporciona funciones para realizar optimización bayesiana de hiperparámetros de manera eficiente y está bien integrada con scikit-learn.
#
#
#
# Basado en lo anterior, crear un pipeline con las siguientes etapas usando **repeated kfold cv:**
#
# 1. Scaler
# 2. KNN
#
# Enseguida, pptimizar los param. de KNN usando optimización bayesiana. Finalmente, evaluar en el conjunto de test.
#
# Tip: Ver BayesSearchCV en https://machinelearningmastery.com/scikit-optimize-for-hyperparameter-tuning-in-machine-learning/

# %%
from skopt import BayesSearchCV
from skopt.space import Integer, Categorical
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
import sklearn.metrics as metrics

# repeated k-fold cv
rkfold = RepeatedStratifiedKFold(n_splits=2, n_repeats=3, random_state=45)

# pipeline: scaler + knn
pipeline_knn_bayes = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier())
])

# espacio de búsqueda bayesiana
search_space = {
    'knn__n_neighbors': Integer(1, 100),
    'knn__weights': Categorical(['uniform', 'distance']),
    'knn__metric': Categorical(['euclidean', 'manhattan', 'cosine'])
}

bayes_search = BayesSearchCV(
    pipeline_knn_bayes,
    search_space,
    n_iter=30,
    scoring='recall',
    cv=rkfold,
    random_state=42,
    verbose=1
)
bayes_search.fit(X_train_undersampled, y_train_undersampled)

print(f'Mejor recall en el conj. de validación: {bayes_search.best_score_} para {bayes_search.best_params_}')

# evaluamos en el conjunto de test con el mejor estimador encontrado
pipeline_knn_bayes = bayes_search.best_estimator_
pred_test = pipeline_knn_bayes.predict(X_test)
f1score = metrics.f1_score(y_test, pred_test)
acc = metrics.accuracy_score(y_test, pred_test)
preci = metrics.precision_score(y_test, pred_test)
recall = metrics.recall_score(y_test, pred_test)

print("Para el modelo optimizado (bayesiano), métricas en el conjunto de test: recall = ", recall, ", F1 = ", f1score, ", acc = ", acc, ", precision = ", preci, )
# Out:
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# Mejor recall en el conj. de validación: 0.8693362278585525 para OrderedDict({'knn__metric': 'euclidean', 'knn__n_neighbors': 100, 'knn__weights': 'distance'})
# Para el modelo optimizado (bayesiano), métricas en el conjunto de test: recall =  0.839572192513369 , F1 =  0.5719489981785064 , acc =  0.6664300922640171 , precision =  0.43370165745856354

# %% [markdown]
# # ✅ **Actividad: Voronoi 2D y 3D con TSNE (opcional)**

# %% [markdown]
# 1. **Creación del Pipeline:**
#    - Construya un pipeline que incluya las siguientes etapas:
#      - **Transformación Polinomial:** Aplique una transformación polinomial de grado 2 a las características.
#      - **Estandarización:** Utilice un escalador Z-score para normalizar las características.
#      - **Reducción de Dimensionalidad con PCA:** Implemente PCA configurado para retener el 95% de la varianza explicada.
#      - **Clasificador:** Utilice el algoritmo K-Nearest Neighbors con los siguientes hiperparámetros 'knn__metric': `'euclidean', 'knn__n_neighbors': 100, 'knn__weights': 'distance'`
# 2. Genere el Voronoi Tesselation (VT) del clasificador anterior en 2D y 3D. Utilice TSNE como reductor de dimensionalidad para visualizar el VT

# %% [markdown]
# # ✅ Actividad: k vs train recall and val recall
#
#
# 1. **Creación del Pipeline:**
#    - Construya un pipeline que incluya las siguientes etapas:
#      - **Estandarización:** Utilice un escalador Z-score para normalizar las características.
#      - **Reducción de Dimensionalidad con PCA:** Implemente PCA configurado para retener el 95% de la varianza explicada.
#      - **Clasificador:** Utilice el algoritmo K-Nearest Neighbors.
#
# 2. **Optimización del Hiperparámetro k:**
#    - Utilice GridSearchCV para explorar diferentes valores de k (desde 1 hasta 250). Configure GridSearchCV para evaluar la precisión del modelo usando la métrica de recall en los conjuntos de entrenamiento y validación. Mantenga fijos todos los demás hiperparámetros.
#
# 3. **Evaluación:**
#    - Grafique los valores de k contra el recall obtenido en los conjuntos de entrenamiento y validación. Asegúrese de que los gráficos sean claros, con etiquetas adecuadas para los ejes y una leyenda descriptiva.
#
# 4. **Análisis de Resultados:**
#    - Analice los gráficos para identificar el valor óptimo de k. Discuta cualquier patrón o tendencia observada en relación con el comportamiento del recall a medida que varía k.

# %%
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# k-fold cv
kfold = StratifiedKFold(n_splits=2, shuffle=True, random_state=45)

# pipeline: scaler + PCA (95% varianza) + knn
pipeline_k = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA(n_components=0.95)),
    ('knn', KNeighborsClassifier())
])

# se varía únicamente k, el resto de hiperparámetros queda en su valor por defecto
param_grid = {'knn__n_neighbors': np.arange(1, 251, 1)}

search_k = GridSearchCV(pipeline_k, param_grid, scoring='recall', cv=kfold,
                         return_train_score=True, verbose=1)
search_k.fit(X_train_undersampled, y_train_undersampled)

k_values = param_grid['knn__n_neighbors']
train_recall = search_k.cv_results_['mean_train_score']
val_recall = search_k.cv_results_['mean_test_score']

plt.figure(figsize=(10, 6))
plt.plot(k_values, train_recall, label='Recall en entrenamiento')
plt.plot(k_values, val_recall, label='Recall en validación')
plt.xlabel('k (n_neighbors)')
plt.ylabel('Recall')
plt.title('Recall en entrenamiento y validación vs k (KNN + PCA)')
plt.legend()
plt.grid(True)
plt.show()

best_k = k_values[np.argmax(val_recall)]
print(f'Mejor k según recall de validación: {best_k} (recall val = {val_recall.max():.4f}, recall train = {train_recall[np.argmax(val_recall)]:.4f})')
# Out:
# Fitting 2 folds for each of 250 candidates, totalling 500 fits
# Mejor k según recall de validación: 247 (recall val = 0.8736, recall train = 0.8729)

# %% [markdown]
# # ✅ **Activity: Weighted KNN with Domain-Based Feature Weights and Gaussian Neighbor Weighting**
#
# ### 1. **Custom Distance Metric (Domain-Based Feature Weights)**
#
# * Implement a **custom distance function** that applies **domain-specific weights** to each input feature:
#
#   $$
#   d(x, x') = \sqrt{\sum_i w_i (x_i - x_i')^2}
#   $$
# * The function or method must accept:
#
#   * Two input samples $x, x'$
#   * An array of feature weights $w = [w_1, w_2, ..., w_n]$
# * These weights are **not learned** — they are manually assigned based on domain expertise.
#
#
# ---
#
# ### 2. **Gaussian-Based Neighbor Weighting**
#
# * Fix the number of neighbors to **k = 50**.
# * Apply a **Gaussian function** to weight each neighbor:
#
#   $$
#   w_i = \exp\left(-\frac{d_i^2}{2\sigma^2}\right)
#   $$
# * All 50 neighbors contribute to the prediction, but their influence is **controlled by σ**.
# * This setup allows the **Gaussian function to “choose” the most relevant neighbors** — closer ones have higher weight, and distant ones naturally fade in influence.
# * ❗Note that the weights $w_i$ from Gaussian-based neighbor weighting are not the same as those from the domain-specific weights (feature weighting).
#
# ---
#
# ### 3. **Hyperparameter Optimization**
#
# * Optimize only the **σ (sigma)** parameter.
# * Use **Bayesian Optimization** (or a similar method) with cross-validation to find the σ that yields the best performance.
#
# ---
#
# ### 4. **Evaluation**
#
# * Evaluate the model using **recall** on the **Telco customer churn** dataset (`X_test`, `y_test`).
# * Compare your model’s **recall** to a **baseline KNN classifier** using:
#
#   * Euclidean distance
#   * Uniform weighting (equal neighbor influence)
#
# ---
#
# ### 5. **Analysis**
#
# * Analyze how the **Gaussian weighting with fixed k = 50** affects model behavior.
# * Reflect on:
#
#   * The role of σ in effectively “selecting” influential neighbors
#   * The effect of fixed feature weights
#   * Trade-offs and limitations (e.g., sensitivity to σ)
#   * Potential extensions, such as adaptive weighting

# %% [markdown]
# ### 💡 **Hint: Using `BaseEstimator` for Your Custom KNN Classifier**
#
# To make your custom KNN model compatible with tools like `BayesSearchCV`, `GridSearchCV`, or `cross_val_score`, consider wrapping it in a class that inherits from:
#
# * `sklearn.base.BaseEstimator`
# * `sklearn.base.ClassifierMixin`
#
# This gives you:
#
# * Automatic handling of hyperparameters (like `sigma`)
# * Compatibility with `scikit-learn` model selection tools
# * Clean, modular, reusable code
#
# ---
#
# ### 🧱 Minimal Starting Point
#
# Here’s a simple class to get started:
#
# ```python
# from sklearn.base import BaseEstimator, ClassifierMixin
# import numpy as np
#
# class GaussianWeightedKNN(BaseEstimator, ClassifierMixin):
#     def __init__(self, sigma=1.0, k=50, feature_weights=None):
#         self.sigma = sigma
#         self.k = k
#         self.feature_weights = feature_weights
#
#     def fit(self, X, y):
#         self.X_train = X
#         self.y_train = y
#         return self
#
#     def predict(self, X):
#         # You will implement the logic for prediction here,
#         # using the Gaussian weights on neighbors and weights on features.
#         pass
# ```
#
# Returning `self` in `fit()` allows the model to be used directly in pipelines and model selection routines.
#
# ---
#
#
# ### 🧠 Why is the `fit` Method Simple in KNN?
#
# KNN is a **lazy learner**:
#
# * It **does not build an internal model** during training.
# * Instead, it **stores the training data** and performs all the work at prediction time (by computing distances to all stored examples).
#
# That’s why the `fit` method just **memorizes** the training data and labels.

# %%
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.neighbors import KNeighborsClassifier
from skopt import BayesSearchCV
from skopt.space import Real
import sklearn.metrics as metrics
import numpy as np


def weighted_distance(x1, x2, weights):
    """d(x, x') = sqrt(sum_i w_i (x_i - x_i')^2), con pesos por dominio."""
    diff = np.asarray(x1) - np.asarray(x2)
    return np.sqrt(np.sum(np.asarray(weights) * diff ** 2))


class GaussianWeightedKNN(BaseEstimator, ClassifierMixin):
    def __init__(self, sigma=1.0, k=50, feature_weights=None):
        self.sigma = sigma
        self.k = k
        self.feature_weights = feature_weights

    def fit(self, X, y):
        self.X_train_ = np.asarray(X, dtype=float)
        self.y_train_ = np.asarray(y)
        self.classes_ = np.unique(self.y_train_)
        if self.feature_weights is None:
            self.feature_weights_ = np.ones(self.X_train_.shape[1])
        else:
            self.feature_weights_ = np.asarray(self.feature_weights, dtype=float)
        return self

    def _weighted_distances_to(self, x):
        # versión vectorizada de weighted_distance contra todo X_train_
        diff = self.X_train_ - x
        return np.sqrt(np.sum(self.feature_weights_ * diff ** 2, axis=1))

    def predict_proba(self, X):
        X = np.asarray(X, dtype=float)
        proba = np.zeros((X.shape[0], len(self.classes_)))
        for i, x in enumerate(X):
            dists = self._weighted_distances_to(x)
            nn_idx = np.argpartition(dists, self.k - 1)[:self.k]
            nn_dists = dists[nn_idx]
            nn_labels = self.y_train_[nn_idx]

            # Gaussian-based neighbor weighting
            gauss_w = np.exp(-(nn_dists ** 2) / (2 * self.sigma ** 2))
            if gauss_w.sum() == 0:
                gauss_w = np.ones_like(gauss_w)

            for c_idx, c in enumerate(self.classes_):
                proba[i, c_idx] = gauss_w[nn_labels == c].sum()
            proba[i] /= proba[i].sum()
        return proba

    def predict(self, X):
        proba = self.predict_proba(X)
        return self.classes_[np.argmax(proba, axis=1)]


# 1) Pesos de características basados en dominio (churn de telecomunicaciones).
#    No se aprenden: se asignan manualmente según qué tan relevante creemos
#    que es cada característica para predecir el churn.
domain_weight_rules = {
    'tenure': 2.0,
    'Contract': 2.5,
    'MonthlyCharges': 1.5,
    'TotalCharges': 1.5,
    'InternetService': 1.3,
    'TechSupport': 1.3,
    'OnlineSecurity': 1.2,
    'PaymentMethod': 1.2,
}


def build_feature_weights(columns, rules, default=1.0):
    weights = np.full(len(columns), default, dtype=float)
    for idx, col in enumerate(columns):
        for key, w in rules.items():
            if col.startswith(key):
                weights[idx] = w
                break
    return weights


feature_weights = build_feature_weights(X_train_undersampled.columns, domain_weight_rules)

# 2) y 3) Gaussian neighbor weighting con k=50 fijo, optimizando solo sigma
#    mediante optimización bayesiana con cross-validation.
kfold = StratifiedKFold(n_splits=2, shuffle=True, random_state=45)

bayes_sigma = BayesSearchCV(
    GaussianWeightedKNN(k=50, feature_weights=feature_weights),
    {'sigma': Real(0.1, 50.0, prior='log-uniform')},
    n_iter=20,
    scoring='recall',
    cv=kfold,
    random_state=42,
    verbose=1
)
bayes_sigma.fit(X_train_undersampled, y_train_undersampled)

print(f'Mejor sigma: {bayes_sigma.best_params_["sigma"]:.4f} (recall val = {bayes_sigma.best_score_:.4f})')

# 4) Evaluación en el conjunto de test, comparando contra un KNN baseline
#    (distancia euclidiana, pesos uniformes).
best_weighted_knn = bayes_sigma.best_estimator_
pred_weighted = best_weighted_knn.predict(X_test)
recall_weighted = metrics.recall_score(y_test, pred_weighted)

baseline_knn = KNeighborsClassifier(n_neighbors=50, metric='euclidean', weights='uniform')
baseline_knn.fit(X_train_undersampled, y_train_undersampled)
pred_baseline = baseline_knn.predict(X_test)
recall_baseline = metrics.recall_score(y_test, pred_baseline)

print(f'Recall en test - Gaussian Weighted KNN (sigma óptimo, k=50): {recall_weighted:.4f}')
print(f'Recall en test - KNN baseline (euclidean, uniform, k=50):    {recall_baseline:.4f}')
# Out:
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Mejor sigma: 20.7256 (recall val = 0.7365)
# Recall en test - Gaussian Weighted KNN (sigma óptimo, k=50): 0.7567
# Recall en test - KNN baseline (euclidean, uniform, k=50):    0.6658
